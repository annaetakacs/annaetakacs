# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
GEI = pd.read_csv('Genger_equality_index_clean.csv')

# %%
GEI.head(10)
# Out:
#    Unnamed: 0  year Country  Gender Equality Index       WORK  Participation  \
# 0           1  2005      AT              59.493698  73.746640      77.009121
# 1           2  2005      BE              66.015660  71.033628      72.269560
# 2           3  2005      BG              56.034705  67.283091      77.931781
# 3           4  2005      CY              45.932332  66.272406      78.509500
# 4           5  2005      CZ              53.560715  65.325624      79.600581
# 5           6  2005      DE              60.047863  68.135481      75.554186
# 6           7  2005      DK              74.582734  78.863634      88.492815
# 7           8  2005      EE              52.203479  71.031004      87.184928
# 8           9  2005      EL              46.830306  62.523323      68.042957
# 9          10  2005      ES              62.171865  68.112330      70.885819
#
#    Segregation and quality of work      MONEY  Financial resources  \
# ...

# %%
GEI.groupby('Country')['Gender Equality Index'].mean()
# Out:
# Country
# AT       61.618740
# BE       69.423132
# BG       56.946941
# CY       51.386466
# CZ       55.032143
# DE       63.989573
# DK       75.936547
# EE       55.120696
# EL       49.346061
# ES       66.874373
# EU-28    64.882329
# FI       73.180381
# FR       69.759873
# HR       52.778986
# HU       51.272610
# IE       67.159995
# IT       56.824079
# LT       55.430453
# LU       65.944717
# LV       56.487352
# MT       58.161511
# NL       72.159565
# PL       55.365871
# PT       54.777848
# RO       51.755599
# SE       80.965256
# SI       65.255828
# SK       52.889217
# UK       70.492678
# Name: Gender Equality Index, dtype: float64

# %%
GEI.describe()
# Out:
#        Unnamed: 0         year  Gender Equality Index        WORK  \
# count  145.000000   145.000000             145.000000  145.000000
# mean    73.000000  2011.800000              61.421339   70.959074
# std     42.001984     4.180975               8.759869    4.572814
# min      1.000000  2005.000000              45.932332   60.762404
# 25%     37.000000  2010.000000              54.100000   67.488017
# 50%     73.000000  2012.000000              59.900000   71.400000
# 75%    109.000000  2015.000000              68.400000   73.800000
# max    145.000000  2017.000000              83.600000   83.000000
#
#        Participation  Segregation and quality of work       MONEY  \
# count     145.000000                       145.000000  145.000000
# mean       80.212974                        63.037149   76.269021
# std         6.856365                         5.989834    9.351766
# min        51.396510                        53.100000   53.217922
# ...
